# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityaSinghDevs/tesseract/blob/design-and-benchmarking/benchmarks/notebooks/tesseract_benchmark_inf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf /content/tesseract

# %%
# !nvidia-smi
# Out:
# Tue Jan 13 17:17:40 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !lscpu
# Out:
# Architecture:                x86_64
#   CPU op-mode(s):            32-bit, 64-bit
#   Address sizes:             46 bits physical, 48 bits virtual
#   Byte Order:                Little Endian
# CPU(s):                      2
#   On-line CPU(s) list:       0,1
# Vendor ID:                   GenuineIntel
#   Model name:                Intel(R) Xeon(R) CPU @ 2.00GHz
#     CPU family:              6
#     Model:                   85
#     Thread(s) per core:      2
#     Core(s) per socket:      1
#     Socket(s):               1
#     Stepping:                3
#     BogoMIPS:                4000.36
#     Flags:                   fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pg
#                              e mca cmov pat pse36 clflush mmx fxsr sse sse2 ss h
#                              t syscall nx pdpe1gb rdtscp lm constant_tsc rep_goo
#                              d nopl xtopology nonstop_tsc cpuid tsc_known_freq p
# ...

# %%
# !free -h
# Out:
#                total        used        free      shared  buff/cache   available
# Mem:            12Gi       801Mi       6.8Gi       3.0Mi       5.0Gi        11Gi
# Swap:             0B          0B          0B

# %%
# !lsb_release -a
# Out:
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 22.04.4 LTS
# Release:	22.04
# Codename:	jammy

# %%
import sys, torch
print("Python:", sys.version)
print("PyTorch:", torch.__version__)
print("Torch CUDA:", torch.version.cuda)
# Out:
# Python: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# PyTorch: 2.9.0+cu126
# Torch CUDA: 12.6

# %%
# !git clone https://github.com/AdityaSinghDevs/tesseract
# Out:
# Cloning into 'tesseract'...
# remote: Enumerating objects: 522, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 522 (delta 36), reused 64 (delta 21), pack-reused 436 (from 1)
# Receiving objects: 100% (522/522), 17.62 MiB | 14.50 MiB/s, done.
# Resolving deltas: 100% (220/220), done.

# %%
# %cd tesseract/
# Out:
# /content/tesseract

# %%
# !git fetch --all
# !git checkout -b design-and-benchmarking origin/design-and-benchmarking
# Out:
# Fetching origin
# Branch 'design-and-benchmarking' set up to track remote branch 'design-and-benchmarking' from 'origin'.
# Switched to a new branch 'design-and-benchmarking'

# %%
# !git branch
# Out:
# * design-and-benchmarking
#   main

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-install-pt26kqr8/clip_21d50d99263d48948bb7830147c58886
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-install-pt26kqr8/clip_21d50d99263d48948bb7830147c58886
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# ...

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
# !ls
# Out:
# api	    docs	 notebooks	   shap_e_model_cache
# app.py	    __init__.py  PERFORMANCE.md    tesseract
# benchmarks  LICENSE	 README.md	   tests
# cli.py	    main.py	 render.py	   THIRD_PARTY_LICENSES.md
# DESIGN.md   new.md	 requirements.txt

# %%
# %env PYTHONPATH=/content/tesseract/tesseract/core
# Out:
# env: PYTHONPATH=/content/tesseract/tesseract/core

# %%
# !python -m benchmarks.scripts.benchmark_inference
# Out:
# __main__- INFO - Starting inference latency benchmark
# __main__- INFO - Config = baseline, Device = gpu, Batch Size = 1 , Runs = 3
# __main__- INFO - Initializing device and loading models
# tesseract.core.model_loader- INFO - CUDA found, device : Tesla T4
# /content/tesseract/tesseract/core/shap_e/models/nn/checkpoint.py:31: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /content/tesseract/tesseract/core/shap_e/models/nn/checkpoint.py:43: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /content/tesseract/tesseract/core/shap_e/models/nn/checkpoint.py:61: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# ...
